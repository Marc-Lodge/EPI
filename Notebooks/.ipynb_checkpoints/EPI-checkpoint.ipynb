# %% [markdown]
# # Part 1. Pitch & Problem Statement
#
# # What are the Greenest Countries in the World, and why?
#
# # What can be learnt from these Nations, if anything, that can be applied to other nations further behind?
#
# Can we use data science techniques to predict and prescribe solutions for energy use in growing populations?
#
# Knowing that energy consumption does not have a linear relationship with population size, can we use data science to find out why?
#
# Can we then use this information to prescribe 'best practices' for growing nations so they can have the same standards of living as developed countries while allowing them to 'leapfrog' some of the known issues?
#
# Using the dataset(s) provided by Yale https://epi.yale.edu/downloads, where they rank countries progress in this regard using the EPI, 'Environmental Performance index', with added data from World Bank group https://data.worldbank.org/ (for metrics like GDP and population size), can I predict EPI using GDP, Population and other variables to build some helpful data that can give us insight into the problem statement.

# %% [markdown]
# # Part 2. Dataset & Data Collection

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(font_scale=1.5)

# %%
# Environmental performance index Abbreviations Explained and later re-used for column renaming
abb = pd.read_csv(
    'epi2020indicator.csv')
abb.head()
# Out:
#               Type Abbreviation                         Variable  \
# 0              EPI          EPI  Environmental Performance Index
# 1  PolicyObjective          HLT             Environmental Health
# 2    IssueCategory          AIR                      Air Quality
# 3        Indicator          PMD                   PM2.5 exposure
# 4        Indicator          HAD            Household solid fuels
#
#               Short name  Order
# 0                    EPI      1
# 1                 Health      2
# 2            Air Quality      3
# 3                  PM2.5      4
# 4  Household solid fuels      5

# %%
# Environmental performance index: Global metrics for the environment: Ranking country performance on sustainability issues
ep = pd.read_csv(
    'epi2020results.csv')
ep.head()
# Out:
#                 country                     region  Population 2020  \
# 0           Afghanistan              Southern Asia         38928341
# 1                Angola         Sub-Saharan Africa         32866268
# 2               Albania             Eastern Europe          2837743
# 3  United Arab Emirates        Greater Middle East          9890400
# 4             Argentina  Latin America & Caribbean         45376763
#
#    GDP Per Capita  EPI.new  HLT.new  AIR.new  PMD.new  HAD.new  OZD.new  ...  \
# 0             517     25.5     20.0     17.7     25.4      7.3     16.9  ...
# 1            1776     29.7     20.4     26.8     32.6     17.8     34.4  ...
# 2            5246     49.0     44.5     41.2     44.2     34.6     60.1  ...
# 3           36285     55.6     55.2     48.6     13.9    100.0     18.8  ...
# 4            8579     52.2     60.2     56.9     54.7     60.9     48.7  ...
#
#    LCB.rnk.new  GIB.rnk.new  GHP.rnk.new  APE.rnk.new  SDA.rnk.new  \
# 0          1.0           77            1          179          176
# 1        136.0           67           78          176          174
# 2         26.0          130           87            1            1
# 3        151.0          165          172           46            1
# 4         67.0          132          132           88           89
#
#    NXA.rnk.new  AGR.rnk.new  SNM.rnk.new  WRS.rnk.new  WWT.rnk.new
# 0          176           48           48          134          134
# 1          176          123          123          134          134
# 2            1           94           94           92           92
# 3           69          169          169           21           21
# 4           90            2            2           77           77
#
# [5 rows x 142 columns]

# %% [markdown]
# # Part 3. EDA & Preliminary Analysis
#
# Quantitatively describe and visualise your data.

# %%
# abb['Short name']
new_columns_dict = {
    'country':'Country', 
    'region':'Region',
    'Population 2020':'Population', 
    'GDP Per Capita':'GDP',
    'EPI.new':'EPI',
    'HLT.new':'Health',
    'AIR.new':'Air Quality',
    'PMD.new':'PM2.5',
    'HAD.new':'Household solid fuels',
    'OZD.new':'Ozone',
    'H2O.new':'Sanitation & Drinking Water',
    'USD.new':'Unsafe Sanitation',
    'UWD.new':'Unsafe Drinking water',
    'HMT.new':'Heavy Metals',
    'PBD.new':'Lead',
    'WMG.new':'Waste Management',
    'MSW.new':'Solid waste',
    'ECO.new':'Ecosystem Vitality',
    'BDH.new':'Biodiversity',
    'TBN.new':'Terrestrial biomes national',
    'TBG.new':'Terrestrial biomes global',
    'MPA.new':'Marine protected areas',
    'PAR.new':'Protected Areas Rep. Ind.',
    'SHI.new':'Species Habitat Index',
    'SPI.new':'Species Protection Index',
    'BHV.new':'Biodiversity Habitat Index',
    'ECS.new':'Ecosystem Services',
    'TCL.new':'Tree cover loss',
    'GRL.new':'Grassland loss',
    'WTL.new':'Wetland loss',
    'FSH.new':'Fisheries',
    'FSS.new':'Fish Stock Status',
    'RMS.new':'Marine Trophic Index',
    'FGT.new':'Fish caught by trawling',
    'CCH.new':'Climate Change',
    'CDA.new':'CO2 growth rate',
    'CHA.new':'CH4 growth rate',
    'FGA.new':'F-gas growth rate',
    'NDA.new':'N2O growth rate',
    'BCA.new':'Black Carbon growth rate',
    'LCB.new':'CO2 from land cover',
    'GIB.new':'GHG intensity trend',
    'GHP.new':'GHG per capita',
    'APE.new':'Pollution Emissions',
    'SDA.new':'SO2 growth rate',
    'NXA.new':'NOx growth rate',
    'AGR.new':'Agriculture',
    'SNM.new':'Sustainable N Mgmt Index',
    'WRS.new':'Water Resources',
    'WWT.new':'Wastewater treatment',
}

ep.rename(columns=new_columns_dict, inplace=True)

# %%
# Move predictor variable to the beginning
col = ep.pop('EPI')
ep.insert(0, col.name, col)
ep.head()
ep.to_csv('ep.csv')

# %%
# ep['GDP'] = ep['GDP'].div(1000000)
# ep['GDP'] = ep['GDP'].round(2)
# ep['Population'] = ep['Population'].div(1000000)
# ep['Population'] = ep['Population'].round(2)

# %%
# ep.sort_values('EPI', ascending=False, inplace=True)

# %%
ep.head()
# Out:
#     EPI               Country                     Region  Population    GDP  \
# 0  25.5           Afghanistan              Southern Asia    38928341    517
# 1  29.7                Angola         Sub-Saharan Africa    32866268   1776
# 2  49.0               Albania             Eastern Europe     2837743   5246
# 3  55.6  United Arab Emirates        Greater Middle East     9890400  36285
# 4  52.2             Argentina  Latin America & Caribbean    45376763   8579
#
#    Health  Air Quality  PM2.5  Household solid fuels  Ozone  ...  LCB.rnk.new  \
# 0    20.0         17.7   25.4                    7.3   16.9  ...          1.0
# 1    20.4         26.8   32.6                   17.8   34.4  ...        136.0
# 2    44.5         41.2   44.2                   34.6   60.1  ...         26.0
# 3    55.2         48.6   13.9                  100.0   18.8  ...        151.0
# 4    60.2         56.9   54.7                   60.9   48.7  ...         67.0
#
#    GIB.rnk.new  GHP.rnk.new  APE.rnk.new  SDA.rnk.new  NXA.rnk.new  \
# 0           77            1          179          176          176
# 1           67           78          176          174          176
# 2          130           87            1            1            1
# 3          165          172           46            1           69
# 4          132          132           88           89           90
#
#    AGR.rnk.new  SNM.rnk.new  WRS.rnk.new  WWT.rnk.new
# 0           48           48          134          134
# 1          123          123          134          134
# 2           94           94           92           92
# 3          169          169           21           21
# 4            2            2           77           77
#
# [5 rows x 142 columns]

# %%
# Split this into the 3 sections of the data, the new(2020) data(e.g EPI.new), the change over 10 years (e.g. EPI.change), and the rank (e.g. EPI.rnk.new). 

# ***I'll initially be working on 2020 data***

# %%
# EPI 2020
epi = ep.iloc[:,0:50]

# %%
# EPI 10 year change
epic1 = ep.iloc[:,0:5]
epic2 = ep.iloc[:,50:96]
epic = epic1.join(epic2)

# %%
# EPI Rank
epirank1 = ep.iloc[:,0:5]
epirank2 = ep.iloc[:,96:141]
epir = epirank1.join(epirank2)

# %%
# Now for thorough EDA...

# Gives quick overview of which Countries have highest EPI

# epi.sort_values('GDP', ascending=False, inplace=True)

# %%
epi.head()
# Out:
#     EPI               Country                     Region  Population    GDP  \
# 0  25.5           Afghanistan              Southern Asia    38928341    517
# 1  29.7                Angola         Sub-Saharan Africa    32866268   1776
# 2  49.0               Albania             Eastern Europe     2837743   5246
# 3  55.6  United Arab Emirates        Greater Middle East     9890400  36285
# 4  52.2             Argentina  Latin America & Caribbean    45376763   8579
#
#    Health  Air Quality  PM2.5  Household solid fuels  Ozone  ...  \
# 0    20.0         17.7   25.4                    7.3   16.9  ...
# 1    20.4         26.8   32.6                   17.8   34.4  ...
# 2    44.5         41.2   44.2                   34.6   60.1  ...
# 3    55.2         48.6   13.9                  100.0   18.8  ...
# 4    60.2         56.9   54.7                   60.9   48.7  ...
#
#    CO2 from land cover  GHG intensity trend  GHG per capita  \
# 0                100.0                 50.6           100.0
# 1                 27.2                 53.9            60.3
# 2                 78.4                 36.4            58.3
# 3                 15.0                 19.8             0.0
# 4                 57.8                 36.2            29.8
#
#    Pollution Emissions  SO2 growth rate  NOx growth rate  Agriculture  \
# 0                  0.0              0.0              0.0         51.0
# 1                  2.6              5.2              0.0         29.3
# 2                100.0            100.0            100.0         37.6
# 3                 83.4            100.0             66.7         13.7
# 4                 59.3             67.3             51.3         78.4
#
#    Sustainable N Mgmt Index  Water Resources  Wastewater treatment
# 0                      51.0              0.0                   0.0
# 1                      29.3              0.0                   0.0
# 2                      37.6              2.7                   2.7
# 3                      13.7             76.8                  76.8
# 4                      78.4              5.9                   5.9
#
# [5 rows x 50 columns]

# %%
# Know shape of dataset
epi.shape
# Out:
# (176, 50)

# %%
epi.columns
# Out:
# Index(['EPI', 'Country', 'Region', 'Population', 'GDP', 'Health',
#        'Air Quality', 'PM2.5', 'Household solid fuels', 'Ozone',
#        'Sanitation & Drinking Water', 'Unsafe Sanitation',
#        'Unsafe Drinking water', 'Heavy Metals', 'Lead', 'Waste Management',
#        'Solid waste', 'Ecosystem Vitality', 'Biodiversity',
#        'Terrestrial biomes national', 'Terrestrial biomes global',
#        'Marine protected areas', 'Protected Areas Rep. Ind.',
#        'Species Habitat Index', 'Species Protection Index',
#        'Biodiversity Habitat Index', 'Ecosystem Services', 'Tree cover loss',
#        'Grassland loss', 'Wetland loss', 'Fisheries', 'Fish Stock Status',
#        'Marine Trophic Index', 'Fish caught by trawling', 'Climate Change',
#        'CO2 growth rate', 'CH4 growth rate', 'F-gas growth rate',
#        'N2O growth rate', 'Black Carbon growth rate', 'CO2 from land cover',
#        'GHG intensity trend', 'GHG per capita', 'Pollution Emissions',
#        'SO2 growth rate', 'NOx growth rate', 'Agriculture',
#        'Sustainable N Mgmt Index', 'Water Resources', 'Wastewater treatment'],
#       dtype='object')

# %%
epi.dtypes
# Out:
# EPI                            float64
# Country                         object
# Region                          object
# Population                       int64
# GDP                              int64
# Health                         float64
# Air Quality                    float64
# PM2.5                          float64
# Household solid fuels          float64
# Ozone                          float64
# Sanitation & Drinking Water    float64
# Unsafe Sanitation              float64
# Unsafe Drinking water          float64
# Heavy Metals                   float64
# Lead                           float64
# Waste Management               float64
# Solid waste                    float64
# Ecosystem Vitality             float64
# Biodiversity                   float64
# Terrestrial biomes national    float64
# Terrestrial biomes global      float64
# Marine protected areas         float64
# Protected Areas Rep. Ind.      float64
# Species Habitat Index          float64
# Species Protection Index       float64
# Biodiversity Habitat Index     float64
# Ecosystem Services             float64
# Tree cover loss                float64
# Grassland loss                 float64
# Wetland loss                   float64
# Fisheries                      float64
# Fish Stock Status              float64
# Marine Trophic Index           float64
# Fish caught by trawling        float64
# Climate Change                 float64
# CO2 growth rate                float64
# CH4 growth rate                float64
# F-gas growth rate              float64
# N2O growth rate                float64
# Black Carbon growth rate       float64
# CO2 from land cover            float64
# GHG intensity trend            float64
# GHG per capita                 float64
# Pollution Emissions            float64
# SO2 growth rate                float64
# NOx growth rate                float64
# Agriculture                    float64
# Sustainable N Mgmt Index       float64
# Water Resources                float64
# Wastewater treatment           float64
# dtype: object

# %%
# Gives quick overview of EPI per country
epi[['EPI', 'Country']].head()
# Out:
#     EPI               Country
# 0  25.5           Afghanistan
# 1  29.7                Angola
# 2  49.0               Albania
# 3  55.6  United Arab Emirates
# 4  52.2             Argentina

# %%
# Gives quick overview of GDP
epi.sort_values('GDP', ascending=False, inplace=False)
epi.head()
# Out:
#     EPI               Country                     Region  Population    GDP  \
# 0  25.5           Afghanistan              Southern Asia    38928341    517
# 1  29.7                Angola         Sub-Saharan Africa    32866268   1776
# 2  49.0               Albania             Eastern Europe     2837743   5246
# 3  55.6  United Arab Emirates        Greater Middle East     9890400  36285
# 4  52.2             Argentina  Latin America & Caribbean    45376763   8579
#
#    Health  Air Quality  PM2.5  Household solid fuels  Ozone  ...  \
# 0    20.0         17.7   25.4                    7.3   16.9  ...
# 1    20.4         26.8   32.6                   17.8   34.4  ...
# 2    44.5         41.2   44.2                   34.6   60.1  ...
# 3    55.2         48.6   13.9                  100.0   18.8  ...
# 4    60.2         56.9   54.7                   60.9   48.7  ...
#
#    CO2 from land cover  GHG intensity trend  GHG per capita  \
# 0                100.0                 50.6           100.0
# 1                 27.2                 53.9            60.3
# 2                 78.4                 36.4            58.3
# 3                 15.0                 19.8             0.0
# 4                 57.8                 36.2            29.8
#
#    Pollution Emissions  SO2 growth rate  NOx growth rate  Agriculture  \
# 0                  0.0              0.0              0.0         51.0
# 1                  2.6              5.2              0.0         29.3
# 2                100.0            100.0            100.0         37.6
# 3                 83.4            100.0             66.7         13.7
# 4                 59.3             67.3             51.3         78.4
#
#    Sustainable N Mgmt Index  Water Resources  Wastewater treatment
# 0                      51.0              0.0                   0.0
# 1                      29.3              0.0                   0.0
# 2                      37.6              2.7                   2.7
# 3                      13.7             76.8                  76.8
# 4                      78.4              5.9                   5.9
#
# [5 rows x 50 columns]

# %%
epi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 176 entries, 0 to 175
# Data columns (total 50 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   EPI                          176 non-null    float64
#  1   Country                      176 non-null    object
#  2   Region                       176 non-null    object
#  3   Population                   176 non-null    int64
#  4   GDP                          176 non-null    int64
#  5   Health                       176 non-null    float64
#  6   Air Quality                  176 non-null    float64
#  7   PM2.5                        176 non-null    float64
#  8   Household solid fuels        176 non-null    float64
#  9   Ozone                        176 non-null    float64
#  10  Sanitation & Drinking Water  176 non-null    float64
#  11  Unsafe Sanitation            176 non-null    float64
#  12  Unsafe Drinking water        176 non-null    float64
#  13  Heavy Metals                 176 non-null    float64
#  14  Lead                         176 non-null    float64
#  15  Waste Management             176 non-null    float64
#  16  Solid waste                  176 non-null    float64
#  17  Ecosystem Vitality           176 non-null    float64
#  18  Biodiversity                 176 non-null    float64
#  19  Terrestrial biomes national  176 non-null    float64
#  20  Terrestrial biomes global    176 non-null    float64
#  21  Marine protected areas       133 non-null    float64
#  22  Protected Areas Rep. Ind.    176 non-null    float64
#  23  Species Habitat Index        152 non-null    float64
#  24  Species Protection Index     152 non-null    float64
#  25  Biodiversity Habitat Index   176 non-null    float64
#  26  Ecosystem Services           172 non-null    float64
#  27  Tree cover loss              164 non-null    float64
#  28  Grassland loss               162 non-null    float64
#  29  Wetland loss                 153 non-null    float64
#  30  Fisheries                    133 non-null    float64
#  31  Fish Stock Status            108 non-null    float64
#  32  Marine Trophic Index         121 non-null    float64
#  33  Fish caught by trawling      75 non-null     float64
#  34  Climate Change               176 non-null    float64
#  35  CO2 growth rate              176 non-null    float64
#  36  CH4 growth rate              176 non-null    float64
#  37  F-gas growth rate            113 non-null    float64
#  38  N2O growth rate              176 non-null    float64
#  39  Black Carbon growth rate     176 non-null    float64
#  40  CO2 from land cover          163 non-null    float64
#  41  GHG intensity trend          176 non-null    float64
#  42  GHG per capita               176 non-null    float64
#  43  Pollution Emissions          176 non-null    float64
#  44  SO2 growth rate              176 non-null    float64
#  45  NOx growth rate              176 non-null    float64
#  46  Agriculture                  176 non-null    float64
#  47  Sustainable N Mgmt Index     176 non-null    float64
#  48  Water Resources              176 non-null    float64
#  49  Wastewater treatment         176 non-null    float64
# dtypes: float64(46), int64(2), object(2)
# memory usage: 68.9+ KB

# %%
epi.isnull().sum()
# Out:
# EPI                              0
# Country                          0
# Region                           0
# Population                       0
# GDP                              0
# Health                           0
# Air Quality                      0
# PM2.5                            0
# Household solid fuels            0
# Ozone                            0
# Sanitation & Drinking Water      0
# Unsafe Sanitation                0
# Unsafe Drinking water            0
# Heavy Metals                     0
# Lead                             0
# Waste Management                 0
# Solid waste                      0
# Ecosystem Vitality               0
# Biodiversity                     0
# Terrestrial biomes national      0
# Terrestrial biomes global        0
# Marine protected areas          43
# Protected Areas Rep. Ind.        0
# Species Habitat Index           24
# Species Protection Index        24
# Biodiversity Habitat Index       0
# Ecosystem Services               4
# Tree cover loss                 12
# Grassland loss                  14
# Wetland loss                    23
# Fisheries                       43
# Fish Stock Status               68
# Marine Trophic Index            55
# Fish caught by trawling        101
# Climate Change                   0
# CO2 growth rate                  0
# CH4 growth rate                  0
# F-gas growth rate               63
# N2O growth rate                  0
# Black Carbon growth rate         0
# CO2 from land cover             13
# GHG intensity trend              0
# GHG per capita                   0
# Pollution Emissions              0
# SO2 growth rate                  0
# NOx growth rate                  0
# Agriculture                      0
# Sustainable N Mgmt Index         0
# Water Resources                  0
# Wastewater treatment             0
# dtype: int64

# %% [markdown]
# As the many columns of environmental data we have are factored into the EPI score using weighting and aggregation...
#
# https://epi.yale.edu/downloads/epi2020weights20200604.csv
#
# ... we can comfortably drop the columns that have missing values as they have already been factored into the score.
#
# We can then focus on other possible predictors that have have an impact on the EPI

# %%
print(epi.shape)
epi = epi.dropna(axis=1, how='any')
print(epi.shape)
# Out:
# (176, 50)
# (176, 37)

# %%
# This shows the correlation of all variables to the EPI

epi.corr().sort_values('EPI', ascending=False)
# Out:
#                                   EPI  Population       GDP    Health  \
# EPI                          1.000000   -0.088416  0.797989  0.939378
# Health                       0.939378   -0.074636  0.834596  1.000000
# Unsafe Drinking water        0.921150   -0.028185  0.792817  0.963767
# Sanitation & Drinking Water  0.915443   -0.034736  0.778425  0.964191
# Ecosystem Vitality           0.895579   -0.089490  0.604377  0.688747
# Air Quality                  0.886548   -0.113927  0.832173  0.961203
# Unsafe Sanitation            0.885503   -0.042986  0.739897  0.941546
# Household solid fuels        0.850027   -0.059397  0.766640  0.910160
# Climate Change               0.822478   -0.002023  0.541901  0.701658
# Water Resources              0.822353   -0.035913  0.799198  0.807488
# Wastewater treatment         0.822353   -0.035913  0.799198  0.807488
# Waste Management             0.803705   -0.001475  0.647393  0.818873
# Solid waste                  0.803705   -0.001475  0.647393  0.818873
# GDP                          0.797989   -0.034923  1.000000  0.834596
# Heavy Metals                 0.790854   -0.120777  0.723683  0.832528
# Lead                         0.790854   -0.120777  0.723683  0.832528
# CO2 growth rate              0.786777   -0.025281  0.533452  0.684382
# Pollution Emissions          0.728046   -0.044233  0.544099  0.631249
# NOx growth rate              0.725665   -0.054391  0.538815  0.617133
# PM2.5                        0.663350   -0.120128  0.660761  0.725880
# SO2 growth rate              0.578908   -0.024363  0.436245  0.514415
# Black Carbon growth rate     0.561390   -0.037279  0.408244  0.479412
# CH4 growth rate              0.528572   -0.039296  0.321269  0.451368
# Biodiversity                 0.486947   -0.129909  0.291753  0.284769
# N2O growth rate              0.382293    0.004978  0.254207  0.307051
# Terrestrial biomes national  0.380199   -0.156387  0.218850  0.243560
# Terrestrial biomes global    0.352886   -0.135213  0.200827  0.207153
# Agriculture                  0.349069    0.110858  0.195693  0.258213
# Sustainable N Mgmt Index                 0.335141
# Ozone                                    0.102646
# Protected Areas Rep. Ind.                0.106156
# GHG intensity trend                      0.146340
# Population                              -0.035913
# Biodiversity Habitat Index               0.002939
# GHG per capita                          -0.596569
#
# [35 rows x 35 columns]

# %% [markdown]
# As you can see from above, most of the individual environmental indicators are highly correlated to the EPI.
#
# In a sense, the EPI contains the info for all of the environmental indicators. As such, what I'll do now is drop the 32 individual environmental indicators and just use the 11 issue categories (mentioned in the indicator sheet, and minus those with missing values) and add in the EPI change over 10 years, then the EPI rank.

# %%
ic = (abb[abb['Type'] == 'IssueCategory'])
ic
# Out:
#              Type Abbreviation                     Variable  \
# 2   IssueCategory          AIR                  Air Quality
# 6   IssueCategory          H2O  Sanitation & Drinking Water
# 9   IssueCategory          HMT                 Heavy Metals
# 11  IssueCategory          WMG             Waste Management
# 14  IssueCategory          BDH       Biodiversity & Habitat
# 22  IssueCategory          ECS           Ecosystem Services
# 26  IssueCategory          FSH                    Fisheries
# 30  IssueCategory          CCH               Climate Change
# 39  IssueCategory          APE          Pollution Emissions
# 42  IssueCategory          AGR                  Agriculture
# 44  IssueCategory          WRS              Water Resources
#
#                      Short name  Order
# 2                   Air Quality      3
# 6   Sanitation & Drinking Water      7
# 9                  Heavy Metals     10
# 11             Waste Management     12
# 14                 Biodiversity     15
# 22           Ecosystem Services     23
# 26                    Fisheries     27
# 30               Climate Change     31
# 39          Pollution Emissions     40
# 42                  Agriculture     43
# 44              Water Resources     45

# %%
epi.columns
# Out:
# Index(['EPI', 'Country', 'Region', 'Population', 'GDP', 'Health',
#        'Air Quality', 'PM2.5', 'Household solid fuels', 'Ozone',
#        'Sanitation & Drinking Water', 'Unsafe Sanitation',
#        'Unsafe Drinking water', 'Heavy Metals', 'Lead', 'Waste Management',
#        'Solid waste', 'Ecosystem Vitality', 'Biodiversity',
#        'Terrestrial biomes national', 'Terrestrial biomes global',
#        'Protected Areas Rep. Ind.', 'Biodiversity Habitat Index',
#        'Climate Change', 'CO2 growth rate', 'CH4 growth rate',
#        'N2O growth rate', 'Black Carbon growth rate', 'GHG intensity trend',
#        'GHG per capita', 'Pollution Emissions', 'SO2 growth rate',
#        'NOx growth rate', 'Agriculture', 'Sustainable N Mgmt Index',
#        'Water Resources', 'Wastewater treatment'],
#       dtype='object')

# %%
epi = epi.drop(columns=["Health", "PM2.5", "Household solid fuels", "Ozone", "Unsafe Sanitation",
               "Unsafe Drinking water", 'Lead', 'Solid waste', 'Ecosystem Vitality', 'Terrestrial biomes national', 'Terrestrial biomes global',
       'Protected Areas Rep. Ind.', 'Biodiversity Habitat Index', 'CO2 growth rate', 'CH4 growth rate',
       'N2O growth rate', 'Black Carbon growth rate', 'GHG intensity trend',
       'GHG per capita', 'SO2 growth rate',
       'NOx growth rate', 'Agriculture','Sustainable N Mgmt Index','Wastewater treatment'])
epi.head()
# Out:
#     EPI               Country                     Region  Population    GDP  \
# 0  25.5           Afghanistan              Southern Asia    38928341    517
# 1  29.7                Angola         Sub-Saharan Africa    32866268   1776
# 2  49.0               Albania             Eastern Europe     2837743   5246
# 3  55.6  United Arab Emirates        Greater Middle East     9890400  36285
# 4  52.2             Argentina  Latin America & Caribbean    45376763   8579
#
#    Air Quality  Sanitation & Drinking Water  Heavy Metals  Waste Management  \
# 0         17.7                         28.0           0.0               0.0
# 1         26.8                         12.8          37.3               0.0
# 2         41.2                         54.0          46.1               0.0
# 3         48.6                         67.2          54.3              26.8
# 4         56.9                         64.7          73.1              44.6
#
#    Biodiversity  Climate Change  Pollution Emissions  Water Resources
# 0          21.9            22.2                  0.0              0.0
# 1          39.3            49.0                  2.6              0.0
# 2          68.2            56.8                100.0              2.7
# 3          80.9            38.9                 83.4             76.8
# 4          49.1            60.2                 59.3              5.9

# %%
epi = epi.join(epic["EPI.change"])
epi = epi.join(epir["EPI.rnk.new"])

# %%
# Move EPI change variable to the beginning
col = epi.pop("EPI.change")
epi.insert(1, col.name, col)

# %%
# Move EPI rank variable to the beginning
col = epi.pop("EPI.rnk.new")
epi.insert(2, col.name, col)
epi.head()
# Out:
#     EPI  EPI.change  EPI.rnk.new               Country  \
# 0  25.5         5.0          178           Afghanistan
# 1  29.7         5.3          158                Angola
# 2  49.0        10.2           62               Albania
# 3  55.6        11.3           42  United Arab Emirates
# 4  52.2         5.0           54             Argentina
#
#                       Region  Population    GDP  Air Quality  \
# 0              Southern Asia    38928341    517         17.7
# 1         Sub-Saharan Africa    32866268   1776         26.8
# 2             Eastern Europe     2837743   5246         41.2
# 3        Greater Middle East     9890400  36285         48.6
# 4  Latin America & Caribbean    45376763   8579         56.9
#
#    Sanitation & Drinking Water  Heavy Metals  Waste Management  Biodiversity  \
# 0                         28.0           0.0               0.0          21.9
# 1                         12.8          37.3               0.0          39.3
# 2                         54.0          46.1               0.0          68.2
# 3                         67.2          54.3              26.8          80.9
# 4                         64.7          73.1              44.6          49.1
#
#    Climate Change  Pollution Emissions  Water Resources
# 0            22.2                  0.0              0.0
# 1            49.0                  2.6              0.0
# 2            56.8                100.0              2.7
# 3            38.9                 83.4             76.8
# 4            60.2                 59.3              5.9

# %%
epi.rename(columns={'EPI.change':'EPI Change', 'EPI.rnk.new':'EPI Rank'}, inplace=True)
epi.head()
# Out:
#     EPI  EPI Change  EPI Rank               Country  \
# 0  25.5         5.0       178           Afghanistan
# 1  29.7         5.3       158                Angola
# 2  49.0        10.2        62               Albania
# 3  55.6        11.3        42  United Arab Emirates
# 4  52.2         5.0        54             Argentina
#
#                       Region  Population    GDP  Air Quality  \
# 0              Southern Asia    38928341    517         17.7
# 1         Sub-Saharan Africa    32866268   1776         26.8
# 2             Eastern Europe     2837743   5246         41.2
# 3        Greater Middle East     9890400  36285         48.6
# 4  Latin America & Caribbean    45376763   8579         56.9
#
#    Sanitation & Drinking Water  Heavy Metals  Waste Management  Biodiversity  \
# 0                         28.0           0.0               0.0          21.9
# 1                         12.8          37.3               0.0          39.3
# 2                         54.0          46.1               0.0          68.2
# 3                         67.2          54.3              26.8          80.9
# 4                         64.7          73.1              44.6          49.1
#
# Climate Change                          0.711669         0.597965
# Water Resources                         0.615525         1.000000
# Waste Management                        0.540791         0.697752
# GDP                                     0.544099         0.799198
# Heavy Metals                            0.546830         0.724221
# Pollution Emissions                     1.000000         0.615525
# Biodiversity                            0.287085         0.347250
# EPI Change                              0.481872         0.294179
# Population                             -0.044233        -0.035913
# EPI Rank                               -0.718305        -0.733717

# %%
fig = plt.figure(figsize=(15,5))
ax = fig.gca()
sns.scatterplot(y=epi.EPI, x=epi.GDP, hue=epi.Region)
plt.ylabel('EPI')
plt.xlabel('GDP')
plt.title("EPI vs. GDP")
plt.show()

# %%
# Now lets visualise both the change and the rank vs GDP

fig = plt.figure(figsize=(15,5))
ax = fig.gca()
sns.scatterplot(y=epi['EPI Change'], x=epi.GDP, hue=epi.Region)
plt.ylabel('EPI Change')
plt.xlabel('GDP')
plt.title("EPI Change vs. GDP")
plt.show()

# %%
# Now lets visualise the rank vs GDP

fig = plt.figure(figsize=(15,5))
ax = fig.gca()
sns.scatterplot(y=epi['EPI Rank'], x=epi.GDP, hue=epi.Region)
plt.ylabel('EPI Rank')
plt.xlabel('GDP')
plt.title("EPI Rank vs. GDP")
plt.show()

# %% [markdown]
# # What Can We Take From This So Far?
#
# As Pointed out by Yale themselves and as we can see from the data:
#
# - There is a high correlation between a Countries wealth (GDP per capita in this case) and EPI score
#
# - The Region (those being in the Global West faring the best), seems to have a positive correlation with EPI score, this is likely a further extension of Wealth
#
# - And, perhaps unsurprisingly, we have a negative correlation between EPI score and population.
#
# - In terms of the rank, its essentially the EPI in reverse i.e. lower rank is good vs lower EPI is bad.
#
# - And lastly, the 10 year change shows the Global West has stayed neutral to positive, whereas the Middle East and Latine America show the most improvement

# %% [markdown]
# # Part 4: Findings & Technical Report
#
# Share your technical findings with your fellow data scientists.
#
# Explain your goals:
#
# - As mentioned in the problem statement, can we use data to prescribe solutions being carried out by the environmentally more successful Coutries to the less successful Countries? And if not, why not? Already it is becoming clear a Countries Wealth plays a large part in how well they fare, can we find anything more specific than that?
#
# Describe Modeling Choices:
#
# - As the EPI score for 2020 is a continuous target variable, I'll be using regression models for this project.
# - Starting with the below initial modelling, showing the linear regression and baseline for EPI vs GDP
#
# # Linear Regression

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split, cross_val_score, cross_val_predict
from sklearn.metrics import r2_score, mean_squared_error

# %%
fig = plt.figure(figsize=(15,5))
ax = fig.gca()
sns.scatterplot(y=epi.EPI, x=epi.GDP, hue=epi.Region, legend='auto')
sns.regplot(y=epi.EPI, x=epi.GDP, data=epi, ax=ax, color='yellowgreen', scatter=False, line_kws={'linewidth':1})
plt.axhline(epi['EPI'].mean(), color='yellowgreen', linewidth=1)
plt.ylabel('EPI')
plt.xlabel('GDP')
plt.title("EPI vs. GDP")
plt.show()

# %%
df = pd.DataFrame({'Y': epi.EPI, 'X': epi.GDP})

# %%
df.corr().loc['Y', 'X']
# Out:
# 0.7979887073916735

# %%
def sls_fit_pd(df, X, Y):
    y_bar = df['Y'].mean()
    x_bar = df['X'].mean()
    std_y = df['Y'].std()
    std_x = df['X'].std()
    r_xy = df.corr().loc['X', 'Y']
    beta_1 = r_xy * (std_y / std_x)
    beta_0 = y_bar - beta_1*x_bar
    return beta_0, beta_1

# %%
# baseline
df['Mean_Yhat'] = df['Y'].mean()
df['Y'].mean()
# Out:
# 46.46647727272729

# %%
# Calculate MSE
df['Mean_Yhat_SE'] = np.square(df['Y'] - df['Mean_Yhat'])
df['Mean_Yhat_SE'].mean()
# Out:
# 240.54927395402868

# %%
# beta coefficients
beta_0, beta_1 = sls_fit_pd(df, 'Y', 'X')
beta_0, beta_1
# Out:
# (37.79108248116546, 0.0006514570860504083)

# %%
# predictions
df['Linear_Yhat'] = beta_0 + beta_1*df['X']
df['Linear_Yhat']
# Out:
# 0      38.127886
# 1      38.948070
# 2      41.208626
# 3      61.429203
# 4      43.379933
#          ...
# 171    39.660764
# 172    40.441210
# 173    41.475724
# 174    38.432768
# 175    38.582603
# Name: Linear_Yhat, Length: 176, dtype: float64

# %%
# MSE based on predictions
np.square(df['Y'] - df['Linear_Yhat']).mean()
# Out:
# 87.37086949259141

# %%
np.square(df['Y'] - df['Linear_Yhat']).mean()**0.5
# Out:
# 9.347238602528098

# %%
df.head()
# Out:
#       Y      X  Mean_Yhat  Mean_Yhat_SE  Linear_Yhat
# 0  25.5    517  46.466477    439.593169    38.127886
# 1  29.7   1776  46.466477    281.114760    38.948070
# 2  49.0   5246  46.466477      6.418737    41.208626
# 3  55.6  36285  46.466477     83.421237    61.429203
# 4  52.2   8579  46.466477     32.873283    43.379933

# %%
fig, ax = plt.subplots(figsize=(15, 7))

# plot a scatter plot on it with our data
ax.scatter(df['X'], df['Y'], c='k')
ax.plot(df['X'], df['Linear_Yhat'], color='r', lw=1)
ax.set_xlabel('X', fontsize=20)
ax.set_ylabel('Y', fontsize=20)
ax.tick_params(axis='both', labelsize=20)

# %%
# residuals

residuals = df['Y'] - df['Linear_Yhat']
residuals
# Out:
# 0     -12.627886
# 1      -9.248070
# 2       7.791374
# 3      -5.829203
# 4       8.820067
#          ...
# 171   -10.760764
# 172    -3.141210
# 173     1.624276
# 174    -3.732768
# 175    -1.582603
# Length: 176, dtype: float64

# %%
fig, ax = plt.subplots(figsize=(15, 8))

ax.hist(residuals, bins=20, color='b')
ax.set_xlabel(r'$\epsilon$', fontsize=20)
ax.tick_params(axis='both', labelsize=20)

# %%
residuals.sum()
# Out:
# -2.7711166694643907e-12

# %%
residuals.dot(df.X)
# Out:
# -2.3283064365386963e-08

# %%
fig, ax = plt.subplots(figsize=(12, 6))

ax.hist(([df['X'], df['Y']]), label=['X', 'Y'], bins=20, histtype='stepfilled', alpha=0.5)
ax.legend()
ax.tick_params(axis='both', labelsize=20)

# %%
# check for dependence between predictor variable and residuals
plt.scatter(df['X'], residuals)
plt.xlabel('X')
plt.ylabel('residuals')
plt.show()

# %% [markdown]
# Evaluate Model Performance, and discuss results.
#
# -
#
# Data science reporting is technical, but don’t forget that you should tell a compelling story about your data.

# %% [markdown]
# # Part 5: Presentation & Non-Technical Summary
#
# Take your findings and share a presentation that delivers the most important insights from
# your project to a non-technical audience. Tell us the most interesting story about your data.
# Break down your process for a novice audience. Make sure to include compelling visuals.
# Time is short, so be sure to practice and include only the most relevant components of your
# project
